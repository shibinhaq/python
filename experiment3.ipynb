# %%
#to change a string to new string
a=input("enter a string:")
b=a[-1]+a[1:5]+a[0]
print(b)
# Out:
# enter a string: student
# ttudes

# %%
a=input("enter a string")
b=a[:2]+a[-2:]
print(b)
# Out:
# enter a string student
# stnt

# %%
a=input("enter the first string")
b=input("enter the second string")
c=b+a
print(c)
# Out:
# enter the first string mca
# enter the second string student
# studentmca

# %%
a=input("enter a string")
b=a[0]+a[1:].replace(a[3],"$")
print("new string=",b)
# Out:
# enter a string onion
# new string= oni$n
