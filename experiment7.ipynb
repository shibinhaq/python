# %%
#print all colors from colorset 1 not contained in colorset2 
a=set(input("enter the colors separated by commas:").split(","))
b=set(input("enter the colors separated by commas:").split(","))
result=a-b
print("colors in set1 but not in set2:",result)
# Out:
# enter the first set of colors: red,black,yellow
# enter the second set of colors: blue,black,green
# colors in set1 but not in set2: {'yellow', 'red'}

# %%
#print all colors from set1 and set2
a=set(input("enter the colors separated by commas:").split(","))
b=set(input("enter the colors separated by commas:").split(","))
c=a|b
print("colors from set a and set b:",c)
# Out:
# enter the colors separated by commas: red,black,blue
# enter the colors separated by commas: orange,green,blue
# colors from set a and set b: {'red', 'orange', 'blue', 'black', 'green'}
