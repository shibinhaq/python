# %%
#print all colors from colorset 1 not contained in colorset2 
a=set(input("enter the colors separated by commas:").split(","))
b=set(input("enter the colors separated by commas:").split(","))
print("set 1 :",a)
print("set 2 :",b)     
print("colors in set 1 but not in set 2 :",a-b)
# Out:
# enter the colors separated by commas: blue,green,yellow
# enter the colors separated by commas: white,black,yellow
# set 1 : {'blue', 'yellow', 'green'}
# set 2 : {'white', 'yellow', 'black'}
# colors in set 1 but not in set 2 : {'blue', 'green'}

# %%
#print all colors from set1 and set2
a=set(input("enter the colors separated by commas:").split(","))
b=set(input("enter the colors separated by commas:").split(","))
print("set 1 :",a)
print("set 2 :",b)
print("colors from set a and set b:",a|b)
# Out:
# enter the colors separated by commas: blue,green,yellow
# enter the colors separated by commas: black,red
# set 1 : {'blue', 'yellow', 'green'}
# set 2 : {'red', 'black'}
# colors from set a and set b: {'blue', 'green', 'red', 'yellow', 'black'}
